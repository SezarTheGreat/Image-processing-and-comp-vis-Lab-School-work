# %%
import cv2
image1 = cv2.imread("pexels-alexquezada-28888994.jpg")
cv2.imshow("The image is",image1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image_path = 'pexels-alexquezada-28888994.jpg'
resized_img = ""
img = mpimg.imread(image_path)
plt.imshow(img)
plt.show()

# %%
import numpy as np 
from PIL import Image
img = Image.open("pexels-alexquezada-28888994.jpg")
img_np = np.array(img)

resized_np = img_np[::2, ::2]
Image.fromarray(resized_np).show()

# %%
from skimage import io
from skimage.transform import resize
import matplotlib.pyplot as plt

img = io.imread('pexels-alexquezada-28888994.jpg')
resized = resize(img,(300,300),anti_aliasing=True)

plt.imshow(resized)
plt.title("Resized")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from skimage import io
#       2 from skimage.transform import resize
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'skimage'
